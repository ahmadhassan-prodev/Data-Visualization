# %%
import matplotlib.pyplot as plt

# %%
Class = [9,10,11,12]
ahmad_marks = [478,1044,493,1022]
awais_marks = [490,1058,470,980]

plt.bar(Class, ahmad_marks, label="Ahmad Hassan")
plt.xlabel("Class")
plt.ylabel("Marks")
plt.title("Marks over Years")
plt.legend()
plt.show()
